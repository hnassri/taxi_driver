# %%
from algo.QLearning import QLearning 
from algo.DeepQLearning import DeepQLearning 
import matplotlib.pyplot as plt
import numpy as np

# %%
agent = QLearning()

# %%
agent.train()
# Out:
# Entraînement en cours...
# 10 % effectué
# 20 % effectué
# 30 % effectué
# 40 % effectué
# 50 % effectué
# 60 % effectué
# 70 % effectué
# 80 % effectué
# 90 % effectué
# 100 % effectué
# Entraînement terminé
# Calcul des métriques en cours...
# Métriques calculées

# %%
agent.run()

# %%
agent.show_metrics()
# Out:
# Overall Average reward: 0.0
# Overall Average number of steps: 19.752
# Success rate (%): 96.39999999999999
# Number of epochs: 1000
# Training Time(in secondes): 0.499927517001197

# %%
agent.save_model("my_model")

# %%
agent2 = QLearning()
agent2.load_model("my_model.pickle")
agent2.run()

# %%
agent2.train()
# Out:
# Entraînement en cours...
# 10 % effectué
# 20 % effectué
# 30 % effectué
# 40 % effectué
# 50 % effectué
# 60 % effectué
# 70 % effectué
# 80 % effectué
# 90 % effectué
# 100 % effectué
# Entraînement terminé
# Calcul des métriques en cours...
# Métriques calculées

# %%
agent2.show_metrics()
# Out:
# Overall Average reward: 0.0
# Overall Average number of steps: 16.699
# Success rate (%): 98.1
# Number of epochs: 1000
# Training Time(in secondes): 0.5327039900003001

# %%
# It's done to test the raising exception when we pass a bad parameter
agent3 = QLearning(learning_rate=1.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # It's done to test the raising exception when we pass a bad parameter
# ----> 2 agent3 = QLearning(learning_rate=1.5)
#
# File ~/delivery/T-AIA-902-STG_6/algo/QLearning.py:9, in QLearning.__init__(self, learning_rate, gamma, exploration_prob, epsilon_decay, epsilon_min)
#       8 def __init__(self, learning_rate=0.8, gamma=0.95, exploration_prob=0.6, epsilon_decay=0.9995, epsilon_min=0.6):
# ----> 9     self.set_learning_rate(learning_rate)
#      10     self.set_gamma(gamma)
#      11     self.set_exploration_prob(exploration_prob)
#
# File ~/delivery/T-AIA-902-STG_6/algo/QLearning.py:159, in QLearning.set_learning_rate(self, lr)
#     158 def set_learning_rate(self, lr):
# --> 159     if self.__check_is_between_0_and_1(value=lr, name="learning rate"):
#     160         self.learning_rate = lr
#
# ...

# %%
agent = DeepQLearning(learning_rate=0.001, gamma=0.95, exploration_prob=0.99, memory_size=2000, target_net_update_freq=100, batch_size=32, epsilon_decay=0.9995, epsilon_min=0.6)

# %%
agent.train(5000)
# Out:
# Entraînement en cours...
# 10 % effectué
# 20 % effectué
# 30 % effectué
# 40 % effectué
# 50 % effectué
# 60 % effectué
# 70 % effectué
# 80 % effectué
# 90 % effectué
# 100 % effectué
# Entraînement terminé
# Calcul des métriques en cours...
# Métriques calculées

# %%
agent.show_metrics()
# Out:
# Overall Average reward: 0.0
# Overall Average number of steps: 17.93
# Success rate (%): 97.39999999999999
# Number of epochs: 5000
# Training Time(in secondes): 334.67204737499924

# %%
agent.run()

# %%
agent.save_model("my_model_dqn")

# %%
agent2 = DeepQLearning()
agent2.load_model("my_model_dqn.pickle")
agent2.run()

# %%
# It's done to test the raising exception when we pass a bad parameter
agent3 = QLearning(learning_rate=1.5)
